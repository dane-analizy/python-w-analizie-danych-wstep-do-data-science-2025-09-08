# %%
import pandas as pd
import numpy as np

# %%
movie_df = pd.read_csv("dane/film/IMDb_movies.csv")
movie_df
# Out:
# C:\Users\lemur\AppData\Local\Temp\ipykernel_9684\3141829971.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   movie_df = pd.read_csv("dane/film/IMDb_movies.csv")
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# ...

# %%
movie_df.shape # ile wierszy i kolumn
# Out:
# (85855, 22)

# %%
movie_df.columns # nazwy wszystkich kolumn
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
movie_df.dtypes # typy danych w kolumnach
# Out:
# imdb_title_id             object
# title                     object
# original_title            object
# year                      object
# date_published            object
# genre                     object
# duration                   int64
# country                   object
# language                  object
# director                  object
# writer                    object
# production_company        object
# actors                    object
# description               object
# avg_vote                 float64
# votes                      int64
# budget                    object
# usa_gross_income          object
# worlwide_gross_income     object
# metascore                float64
# reviews_from_users       float64
# reviews_from_critics     float64
# dtype: object

# %%
movie_df.describe() # opisuje rozkłady kolumn liczbowych
# Out:
#            duration      avg_vote         votes     metascore  \
# count  85855.000000  85855.000000  8.585500e+04  13305.000000
# mean     100.351418      5.898656  9.493490e+03     55.896881
# std       22.553848      1.234987  5.357436e+04     17.784874
# min       41.000000      1.000000  9.900000e+01      1.000000
# 25%       88.000000      5.200000  2.050000e+02     43.000000
# 50%       96.000000      6.100000  4.840000e+02     57.000000
# 75%      108.000000      6.800000  1.766500e+03     69.000000
# max      808.000000      9.900000  2.278845e+06    100.000000
#
#        reviews_from_users  reviews_from_critics
# count        78258.000000          74058.000000
# mean            46.040826             27.479989
# std            178.511411             58.339158
# min              1.000000              1.000000
# 25%              4.000000              3.000000
# 50%              9.000000              8.000000
# 75%             27.000000             23.000000
# ...

# %%
movie_df.info() # ile niepustych + typy danych
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85855 entries, 0 to 85854
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          85855 non-null  object
#  1   title                  85855 non-null  object
#  2   original_title         85855 non-null  object
#  3   year                   85855 non-null  object
#  4   date_published         85855 non-null  object
#  5   genre                  85855 non-null  object
#  6   duration               85855 non-null  int64
#  7   country                85791 non-null  object
#  8   language               84954 non-null  object
#  9   director               85768 non-null  object
#  10  writer                 84283 non-null  object
#  11  production_company     81400 non-null  object
#  12  actors                 85786 non-null  object
#  13  description            83740 non-null  object
# ...

# %%
movie_df['avg_vote'] = movie_df['avg_vote'].astype(np.int8)

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85855 entries, 0 to 85854
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          85855 non-null  object
#  1   title                  85855 non-null  object
#  2   original_title         85855 non-null  object
#  3   year                   85855 non-null  object
#  4   date_published         85855 non-null  object
#  5   genre                  85855 non-null  object
#  6   duration               85855 non-null  int64
#  7   country                85791 non-null  object
#  8   language               84954 non-null  object
#  9   director               85768 non-null  object
#  10  writer                 84283 non-null  object
#  11  production_company     81400 non-null  object
#  12  actors                 85786 non-null  object
#  13  description            83740 non-null  object
# ...

# %%
movies_2_df = pd.read_csv("dane/film/IMDb_movies.csv",
                          sep=",",
                          usecols=['imdb_title_id', 'title', 'year', 'genre', 'duration', 'country', 'avg_vote', 'votes', 'metascore'],
                          dtype={
                              'imdb_title_id': str,
                              'title': str,
                              'genre': str,
                              'duration': np.int8,
                              'country': str,
                              'avg_vote': float,
                              'votes': np.int16,
                              'metascore': float
                          }
                         )
movies_2_df
# Out:
# C:\Users\lemur\AppData\Local\Temp\ipykernel_9684\213722207.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies_2_df = pd.read_csv("dane/film/IMDb_movies.csv",
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
# ...

# %%
movies_2_df.dtypes
# Out:
# imdb_title_id     object
# title             object
# year              object
# genre             object
# duration            int8
# country           object
# avg_vote         float64
# votes              int16
# metascore        float64
# dtype: object

# %%
movies_2_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85855 entries, 0 to 85854
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   imdb_title_id  85855 non-null  object
#  1   title          85855 non-null  object
#  2   year           85855 non-null  object
#  3   genre          85855 non-null  object
#  4   duration       85855 non-null  int8
#  5   country        85791 non-null  object
#  6   avg_vote       85855 non-null  float64
#  7   votes          85855 non-null  int16
#  8   metascore      13305 non-null  float64
# dtypes: float64(2), int16(1), int8(1), object(5)
# memory usage: 4.8+ MB

# %%
movies_2_df = pd.read_csv("dane/film/IMDb_movies.csv",
                          sep=",",
                          usecols=['imdb_title_id', 'title', 'year', 'genre', 'duration', 'country', 'avg_vote', 'votes', 'metascore'],
                         )
movies_2_df
# Out:
# C:\Users\lemur\AppData\Local\Temp\ipykernel_9684\1385302515.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies_2_df = pd.read_csv("dane/film/IMDb_movies.csv",
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
# ...

# %%
movies_2_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85855 entries, 0 to 85854
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   imdb_title_id  85855 non-null  object
#  1   title          85855 non-null  object
#  2   year           85855 non-null  object
#  3   genre          85855 non-null  object
#  4   duration       85855 non-null  int64
#  5   country        85791 non-null  object
#  6   avg_vote       85855 non-null  float64
#  7   votes          85855 non-null  int64
#  8   metascore      13305 non-null  float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 5.9+ MB

# %%
movie_df.head(100)
# Out:
#    imdb_title_id                        title               original_title  \
# 0      tt0000009                   Miss Jerry                   Miss Jerry
# 1      tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2      tt0001892               Den sorte drøm               Den sorte drøm
# 3      tt0002101                    Cleopatra                    Cleopatra
# 4      tt0002130                    L'Inferno                    L'Inferno
# ..           ...                          ...                          ...
# 95     tt0008150               Joan the Woman               Joan the Woman
# 96     tt0008188          The Little American          The Little American
# 97     tt0008196          The Little Princess          The Little Princess
# 98     tt0008279                   Desiderata               Mater dolorosa
# 99     tt0008309           A Modern Musketeer           A Modern Musketeer
#
#     year date_published                       genre  duration  \
# ...

# %%
movies_2_df.tail(15)
# Out:
#       imdb_title_id                                  title  year  \
# 85840     tt9899850                              Ashoftegi  2019
# 85841     tt9899880                               Columbus  2018
# 85842     tt9900060  Lupin III: La menzogna di Fujiko Mine  2019
# 85843     tt9900782                                 Kaithi  2019
# 85844     tt9903716                                 Jessie  2019
# 85845     tt9904250               La reina de los lagartos  2019
# 85846     tt9904802                            Enemy Lines  2020
# 85847     tt9905412                                  Ottam  2019
# 85848     tt9905462                              Pengalila  2019
# 85849     tt9906644                              Manoharam  2019
# 85850     tt9908390                                Le lion  2020
# 85851     tt9911196         De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774              Padmavyuhathile Abhimanyu  2019
# ...

# %%
movies_2_df.sample(2)
# Out:
#       imdb_title_id              title  year                        genre  \
# 11147     tt0056172  Lawrence d'Arabia  1962  Adventure, Biography, Drama
# 83332     tt7863198         Ya khudeyu  2018                       Comedy
#
#        duration country  avg_vote   votes  metascore
# 11147       228      UK       8.3  261504      100.0
# 83332       102  Russia       6.5    1727        NaN

# %%
movies_2_df.sample(frac=0.05)
# Out:
#       imdb_title_id                       title  year                   genre  \
# 49653     tt0777946                     Mizuchi  2006  Drama, Horror, Mystery
# 6352      tt0041982             Train of Events  1949                   Drama
# 3406      tt0031968                Spia in nero  1939           Thriller, War
# 17003     tt0073001              Pazzi borghesi  1976                  Comedy
# 81137     tt6749072           El peso de la ley  2017   Crime, Drama, Mystery
# ...             ...                         ...   ...                     ...
# 65816     tt2261327        Bir ses böler geceyi  2012                   Drama
# 70734     tt3313054                    Accident  2017        Action, Thriller
# 53023     tt1045898                      Veyyil  2006                   Drama
# 81201     tt6787076          Niemand in de stad  2018                   Drama
# 14144     tt0064781  Ovoce stromu rajských jíme  1970                   Drama
#
# ...
