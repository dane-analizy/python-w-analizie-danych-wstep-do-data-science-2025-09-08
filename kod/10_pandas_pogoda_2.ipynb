# %%
import pandas as pd
from pathlib import Path
from datetime import datetime

# %%
data_dir = Path("dane/pogoda/") 

data_list = []
for file in data_dir.glob("*.xlsx"):
    temp_df = pd.read_excel(file)
    temp_df['nazwa_pliku'] = file.as_posix()
    data_list.append(temp_df)

# %%
len(data_list)
# Out:
# 9

# %%
data_list[2]
# Out:
#       timestamp   temp  temp_feels  temp_min  temp_max  pressure  humidity  \
# 0    1756764092  18.23       18.30     17.13     18.95      1011        84
# 1    1756764122  18.23       18.30     17.13     18.95      1011        84
# 2    1756764182  18.23       18.30     17.13     18.95      1011        84
# 3    1756764423  18.23       18.30     17.13     18.95      1011        84
# 4    1756764513  18.23       18.30     17.13     18.95      1011        84
# ..          ...    ...         ...       ...       ...       ...       ...
# 608  1756849976  22.34       22.51     21.24     23.42      1010        72
# 609  1756850036  22.34       22.51     21.24     23.42      1010        72
# 610  1756850066  22.34       22.51     21.24     23.42      1010        72
# 611  1756850097  22.34       22.51     21.24     23.42      1010        72
# 612  1756850187  22.34       22.51     21.24     23.42      1010        72
#
#      wind_speed            datetime       date
# ...

# %%
big_df = pd.concat( data_list )

# %%
big_df
# Out:
#        timestamp   temp  temp_feels  temp_min  temp_max  pressure  humidity  \
# 0     1756677250  19.64       19.93     18.15     20.77      1013        87
# 1     1756677371  19.48       19.70     18.15     20.65      1013        85
# 0     1756677642  19.48       19.70     18.15     20.65      1013        85
# 1     1756677793  19.45       19.67     18.15     20.65      1013        85
# 2     1756678034  19.35       19.56     18.15     20.65      1012        85
# ...          ...    ...         ...       ...       ...       ...       ...
# 4555  1757329563  25.17       25.00     24.12     26.27      1018        48
# 4556  1757329667  25.21       25.04     24.15     26.30      1018        48
# 4557  1757329758  25.31       25.15     24.15     26.67      1018        48
# 4558  1757329788  25.31       25.15     24.15     26.67      1018        48
# 4559  1757330059  25.31       25.15     24.15     26.67      1018        48
#
#       wind_speed            datetime       date  \
# ...

# %%
big_df.to_excel("dane/pogoda/big.xlsx", index=False)

# %%
# wszystko w jednej linijce
pd.concat( [pd.read_excel(file) for file in data_dir.glob("*.xlsx")] ).to_excel("dane/pogoda/big.xlsx", index=False)
