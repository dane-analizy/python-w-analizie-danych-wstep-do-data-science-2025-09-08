# %%
# biblioteki do wykresów
# !pip install matplotlib seaborn

# %%
import pandas as pd

import numpy as np

# %%
pogoda_df = pd.read_excel("dane/pogoda/big.xlsx")
pogoda_df.head(3)
# Out:
#     timestamp   temp  temp_feels  temp_min  temp_max  pressure  humidity  \
# 0  1756677250  19.64       19.93     18.15     20.77      1013        87
# 1  1756677371  19.48       19.70     18.15     20.65      1013        85
# 2  1756677642  19.48       19.70     18.15     20.65      1013        85
#
#    wind_speed            datetime       date  \
# 0        3.09 2025-08-31 23:54:10 2025-08-31
# 1        3.09 2025-08-31 23:56:11 2025-08-31
# 2        3.09 2025-09-01 00:00:42 2025-09-01
#
#                          nazwa_pliku
# 0  dane/pogoda/2025-08-31-daily.xlsx
# 1  dane/pogoda/2025-08-31-daily.xlsx
# 2  dane/pogoda/2025-09-01-daily.xlsx

# %%
pogoda_df['temp'].plot()
# Out:
# <Axes: >

# %%
pogoda_df['temp'].plot.hist(bins=100, title="Histogram temperatury")
# Out:
# <Axes: title={'center': 'Histogram temperatury'}, ylabel='Frequency'>

# %%
pogoda_df.plot.bar(x='date', y='temp')
# Out:
# <Axes: xlabel='date'>

# %%
pogoda_df.groupby('date', as_index=False).aggregate({"temp":"mean"}).plot.bar(x='date', y='temp')
# Out:
# <Axes: xlabel='date'>

# %%
data = pd.DataFrame({
    'Liczby': np.random.randn(100),
    'X': np.random.rand(100),
    'Y': np.random.rand(100),
    'Kategorie': ['A', 'B', 'C', 'A', 'B'] * 20,
    'Wartość': np.random.randint(1, 10, size=100)
})
data
# Out:
#       Liczby         X         Y Kategorie  Wartość
# 0  -1.545831  0.283136  0.316640         A        6
# 1   1.434365  0.323374  0.498047         B        1
# 2  -2.252267  0.165199  0.996941         C        5
# 3   0.875421  0.032488  0.169298         A        8
# 4  -0.007859  0.814393  0.742956         B        9
# ..       ...       ...       ...       ...      ...
# 95 -0.373045  0.393045  0.922115         A        2
# 96  1.875803  0.816708  0.677104         B        1
# 97  0.192217  0.546629  0.992656         C        5
# 98  0.935052  0.931139  0.121760         A        8
# 99 -0.091302  0.980153  0.261884         B        5
#
# [100 rows x 5 columns]

# %%
data.plot.scatter(x='X', y='Y')
# Out:
# <Axes: xlabel='X', ylabel='Y'>
